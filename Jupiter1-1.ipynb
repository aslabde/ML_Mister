# %%
import requests
from bs4 import BeautifulSoup
# Out:
# /Users/balsaedu/Library/Python/3.8/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
response = requests.get('https://mister.mundodeportivo.com/feed#players')

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
import requests

cookies = {
    'refresh-token': 'eyJhbGciOiJFUzI1NiJ9.eyJleHAiOiI0ODQ3MDI4OTg0IiwicmVmcmVzaCI6InVLM0N1NG1fZ08xM3p5R0w1ajdmVyIsImlkX3Rva2VuX2xpZmV0aW1lX2luX21pbiI6IjUiLCJhbGciOiJFUzI1NiJ9.lbW6viX0SlvotG_i-wx8HE54T_2h_tt5nZib0V0KBhab9LjWquRTOIGcwANZ1_POF3HXo5cJEkx-kuE8wSGWMQ',
    'authenticated': 'true',
    'sui_1pc': '169135538948604B64FF861E07C5C54B3B7559D967A853D36328AFC4',
    '_ga_ru': 'GA1.2.157019.1691355375',
    '_ga_ru_md': 'GA1.2.157019.1691355375',
    '_fbp': 'fb.1.1691355392236.1518909179',
    '_cc_id': '9be0afebfc7364c528dc393a5584ae05',
    'macroleagues_tutorial_seen': '1',
    'didomi_token': '...',
    'euconsent-v2': 'CPy3MMAPy3MMAAHABBENDYCsAP_AAE7AAAiQIkNf_X_fb2vj-_p99_t0eY1P9_6_t6wzjheNE-8NyZ_X_J4Xp2M6rB34pqIKuR4kunLBIQdlHGHcTUgg4IkFqSPsYk2MizNKJ7JEmlMbE2dYGG9vn8TT-ZKY70__f__zvn-r___97oAAhCAABAAAAAgAAIAAAgAIAAAAAAAAAAAAAAAAAAAAAAAADA4tAsy0bqaFsHT0Lpo4igRGjCuJWoBQGUQCwtkBhmTPCnZHAR-wnUAAxAADBByGAFEaAICCIIAkKgIkEOBAqJAIdAACgAUIBAFRIgEoiLAQCAA0B8PAKKAJSLGDKjIidcCMKxIPu-QAAEAQAAIAAQAAAABAJCgAYAAiCgGgAwABEFARABgACIKAqADAAEQUBkAGAAIgoDwAMAARBQIQAYAAiCgTAAwABEFAqABgACIKAAAA.f_gACdgAAAAA',
    'PHPSESSID': 'fguble7s4emvf1dcphs1ke6tia',
    'utm': '%7B%22source%22%3A%22misterfantasy%22%2C%22medium%22%3A%22landing%22%2C%22campaign%22%3A%22landing%22%7D',
    'referer': 'https%3A%2F%2Fwww.misterfantasy.es%2F',
    '_gid': 'GA1.2.1657422768.1697642751',
    '_ga_ru_gid': 'GA1.2.1238991490.1697642751',
    '_ga_ru_md_gid': 'GA1.2.2001425258.1697642751',
    'connectId': '{"ttl":86400000,"lastUsed":1697642751912,"lastSynced":1697642751912}',
    'panoramaId_expiry': '1698247551946',
    'panoramaId': '2572592eeab9c989ed41751f13044945a7021dca77bdde30d12ca4cbf11029d7',
    'panoramaIdType': 'panoIndiv',
    '_pbjs_userid_consent_data': '6495574538250921',
    '_pubcid': '7ecd9069-cc1f-49c8-80bd-3ba5489c21f3',
    'pbjs-unifiedid': '%7B%22TDID_LOOKUP%22%3A%22FALSE%22%2C%22TDID_CREATED_AT%22%3A%222023-10-18T15%3A35%3A07%22%7D',
    '_ga_9VNP59F4BS': 'GS1.1.1697643359.1.0.1697643359.0.0.0',
    'alert_app': '1',
    'cto_bundle': 'FTOC319FbmN3OWVUUlNhbzVOUkdlWW5jbDB0VngwRXFZRGZqNEdYSjFPOUViSDJLcUFJR3E1ZGRqa1VPVzh1OTUlMkZhQmFEJTJCN3NXZXFnNnRwWDNYVmx1YVdENVElMkJlVU84TnkzZlVSZXJ3STE4QTQlMkJIYnZwZzJDNkZOMzNuTUM2Snh1RHFqSGIxakVLWGRJMjBxbjZUOUNnUE5wVmNaWVViT2xaUiUyRjQ2U0hnb3BtaWhFJTNE',
    'cto_bidid': 'F_EmJl9EOWxlYXJFOExJQmZLaFNTeWM2R0ZMZTlSRVU0dng4RE1VcXN5TzM0Z2FNJTJCbVd5cm5oaW8zM3RYSVRvVjNqRmdOQSUyQjN3cjlyZ0oybkhqYjVCZ3dubUp6UHF0NUlYQ09ocnF5b0t6QlZTWnRaWkUyZyUyQmp5RGVxeVpnODVwRTdOUw',
    '_ga': 'GA1.2.157019.1691355375',
    '_ga_9G2QBX7XXH': 'GS1.2.1697656705.5.1.1697657069.0.0.0',
    '_ga_LTJY4YF7RK': 'GS1.2.1697656705.5.1.1697657069.0.0.0',
    '__gads': 'ID=a4852d83240da519:T=1691355392:RT=1697664134:S=ALNI_MasA4bbP60NnGwk6JJ0mDr7sdsmhA',
    '__gpi': 'UID=00000c7a110376e3:T=1691355392:RT=1697664134:S=ALNI_MYuuSMkm5fmK3ydafmEz8WQTTBwRg',
    '___iat_ses': 'BB7B200EB4A47153',
    '___iat_vis': 'BB7B200EB4A47153.7027408f3055916cc073fb4fbe430b6a.1697657069016.7cd3937ed381415f276404382e07d9ce.ROMABEEBBA.11111111.1.0',
    'token': 'eyJhbGciOiJFUzI1NiJ9.eyJleHAiOiIxNjk3NjY1MDM0IiwidXNlcmlkIjoiNjU2MDMiLCJhbGciOiJFUzI1NiJ9.A0KFCFSe6wuApnAo6qDmeRP_si_XwECu4DIe46VZIyftxbzH8GR-2XIc96ZRRi5lhRquLVBsGftedVFPoe989g',
    '_ga_7PVNCJC9CZ': 'GS1.1.1697662965.9.1.1697664734.0.0.0',
    '_ga_NYWVQ5WBZV': 'GS1.1.1697664734.8.0.1697664734.60.0.0',
}

headers = {
    'authority': 'mister.mundodeportivo.com',
    'accept': '*/*',
    'accept-language': 'es-ES,es;q=0.9,en;q=0.8,ca;q=0.7',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    # 'cookie': 'refresh-token=eyJhbGciOiJFUzI1NiJ9.eyJleHAiOiI0ODQ3MDI4OTg0IiwicmVmcmVzaCI6InVLM0N1NG1fZ08xM3p5R0w1ajdmVyIsImlkX3Rva2VuX2xpZmV0aW1lX2luX21pbiI6IjUiLCJhbGciOiJFUzI1NiJ9.lbW6viX0SlvotG_i-wx8HE54T_2h_tt5nZib0V0KBhab9LjWquRTOIGcwANZ1_POF3HXo5cJEkx-kuE8wSGWMQ; authenticated=true; sui_1pc=169135538948604B64FF861E07C5C54B3B7559D967A853D36328AFC4; _ga_ru=GA1.2.157019.1691355375; _ga_ru_md=GA1.2.157019.1691355375; _fbp=fb.1.1691355392236.1518909179; _cc_id=9be0afebfc7364c528dc393a5584ae05; macroleagues_tutorial_seen=1; didomi_token=...; euconsent-v2=CPy3MMAPy3MMAAHABBENDYCsAP_AAE7AAAiQIkNf_X_fb2vj-_p99_t0eY1P9_6_t6wzjheNE-8NyZ_X_J4Xp2M6rB34pqIKuR4kunLBIQdlHGHcTUgg4IkFqSPsYk2MizNKJ7JEmlMbE2dYGG9vn8TT-ZKY70__f__zvn-r___97oAAhCAABAAAAAgAAIAAAgAIAAAAAAAAAAAAAAAAAAAAAAAADA4tAsy0bqaFsHT0Lpo4igRGjCuJWoBQGUQCwtkBhmTPCnZHAR-wnUAAxAADBByGAFEaAICCIIAkKgIkEOBAqJAIdAACgAUIBAFRIgEoiLAQCAA0B8PAKKAJSLGDKjIidcCMKxIPu-QAAEAQAAIAAQAAAABAJCgAYAAiCgGgAwABEFARABgACIKAqADAAEQUBkAGAAIgoDwAMAARBQIQAYAAiCgTAAwABEFAqABgACIKAAAA.f_gACdgAAAAA; PHPSESSID=fguble7s4emvf1dcphs1ke6tia; utm=%7B%22source%22%3A%22misterfantasy%22%2C%22medium%22%3A%22landing%22%2C%22campaign%22%3A%22landing%22%7D; referer=https%3A%2F%2Fwww.misterfantasy.es%2F; _gid=GA1.2.1657422768.1697642751; _ga_ru_gid=GA1.2.1238991490.1697642751; _ga_ru_md_gid=GA1.2.2001425258.1697642751; connectId={"ttl":86400000,"lastUsed":1697642751912,"lastSynced":1697642751912}; panoramaId_expiry=1698247551946; panoramaId=2572592eeab9c989ed41751f13044945a7021dca77bdde30d12ca4cbf11029d7; panoramaIdType=panoIndiv; _pbjs_userid_consent_data=6495574538250921; _pubcid=7ecd9069-cc1f-49c8-80bd-3ba5489c21f3; pbjs-unifiedid=%7B%22TDID_LOOKUP%22%3A%22FALSE%22%2C%22TDID_CREATED_AT%22%3A%222023-10-18T15%3A35%3A07%22%7D; _ga_9VNP59F4BS=GS1.1.1697643359.1.0.1697643359.0.0.0; alert_app=1; cto_bundle=FTOC319FbmN3OWVUUlNhbzVOUkdlWW5jbDB0VngwRXFZRGZqNEdYSjFPOUViSDJLcUFJR3E1ZGRqa1VPVzh1OTUlMkZhQmFEJTJCN3NXZXFnNnRwWDNYVmx1YVdENVElMkJlVU84TnkzZlVSZXJ3STE4QTQlMkJIYnZwZzJDNkZOMzNuTUM2Snh1RHFqSGIxakVLWGRJMjBxbjZUOUNnUE5wVmNaWVViT2xaUiUyRjQ2U0hnb3BtaWhFJTNE; cto_bidid=F_EmJl9EOWxlYXJFOExJQmZLaFNTeWM2R0ZMZTlSRVU0dng4RE1VcXN5TzM0Z2FNJTJCbVd5cm5oaW8zM3RYSVRvVjNqRmdOQSUyQjN3cjlyZ0oybkhqYjVCZ3dubUp6UHF0NUlYQ09ocnF5b0t6QlZTWnRaWkUyZyUyQmp5RGVxeVpnODVwRTdOUw; _ga=GA1.2.157019.1691355375; _ga_9G2QBX7XXH=GS1.2.1697656705.5.1.1697657069.0.0.0; _ga_LTJY4YF7RK=GS1.2.1697656705.5.1.1697657069.0.0.0; __gads=ID=a4852d83240da519:T=1691355392:RT=1697664134:S=ALNI_MasA4bbP60NnGwk6JJ0mDr7sdsmhA; __gpi=UID=00000c7a110376e3:T=1691355392:RT=1697664134:S=ALNI_MYuuSMkm5fmK3ydafmEz8WQTTBwRg; ___iat_ses=BB7B200EB4A47153; ___iat_vis=BB7B200EB4A47153.7027408f3055916cc073fb4fbe430b6a.1697657069016.7cd3937ed381415f276404382e07d9ce.ROMABEEBBA.11111111.1.0; token=eyJhbGciOiJFUzI1NiJ9.eyJleHAiOiIxNjk3NjY1MDM0IiwidXNlcmlkIjoiNjU2MDMiLCJhbGciOiJFUzI1NiJ9.A0KFCFSe6wuApnAo6qDmeRP_si_XwECu4DIe46VZIyftxbzH8GR-2XIc96ZRRi5lhRquLVBsGftedVFPoe989g; _ga_7PVNCJC9CZ=GS1.1.1697662965.9.1.1697664734.0.0.0; _ga_NYWVQ5WBZV=GS1.1.1697664734.8.0.1697664734.60.0.0',
    'origin': 'https://mister.mundodeportivo.com',
    'referer': 'https://mister.mundodeportivo.com/feed',
    'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Mobile Safari/537.36',
    'x-auth': '516586fb93df5f7e5bd8dfd0efb20a1b',
    'x-requested-with': 'XMLHttpRequest',
}

data = {
    'post': 'players',
    'filters[position]': '0',
    'filters[value]': '0',
    'filters[team]': '0',
    'filters[injured]': '0',
    'filters[favs]': '0',
    'filters[owner]': '0',
    'filters[benched]': '0',
    'offset': '0',
    'order': '0',
    'name': '',
    'filtered': '0',
    'parentElement': '.sw-content',
}

response = requests.post('https://mister.mundodeportivo.com/ajax/sw', cookies=cookies, headers=headers, data=data)

# %%
response.status_code
# Out:
# 200

# %%
players = response.json()

# %%
players
# Out:
# {'status': 'ok',
#  'data': {'id': False,
#   'players': [{'id': 53114,
#     'name': 'Jude Bellingham',
#     'position': 3,
#     'id_team': 15,
#     'points': 110,
#     'avg': 13.8,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1686904061,
#     'streak': [{'points': '-', 'color': 0},
#      {'points': 15, 'color': 4},
#      {'points': 19, 'color': 4}],
#     'streak_sum': 34,
#     'value': 20921000,
#     'prev_value': 20897000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 31381500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/53114.png?version=20230616102741',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/15.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 17,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/17.png?version=20231018'}},
#    {'id': 19562,
#     'name': 'Takefusa Kubo',
#     'position': 3,
#     'id_team': 16,
#     'points': 82,
#     'avg': 10.3,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1566483595,
#     'streak': [{'points': '-', 'color': 0},
#      {'points': 12, 'color': 4},
#      {'points': 4, 'color': 2}],
#     'streak_sum': 16,
#     'value': 18144000,
#     'prev_value': 18104000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 27216000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/19562.png?version=20190822161955',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/16.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 408,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/408.png?version=20231018'}},
#    {'id': 29,
#     'name': 'Iñaki Williams',
#     'position': 4,
#     'id_team': 1,
#     'points': 78,
#     'avg': 8.7,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1437662345,
#     'streak': [{'points': 11, 'color': 4},
#      {'points': 5, 'color': 3},
#      {'points': 9, 'color': 3}],
#     'streak_sum': 25,
#     'value': 14925000,
#     'prev_value': 14816000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 22387500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/29.png?version=20150723163905',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 3,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018'}},
#    {'id': 464,
#     'name': 'Aleix García',
#     'position': 3,
#     'id_team': 222,
#     'points': 77,
#     'avg': 8.6,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1437662346,
#     'streak': [{'points': 10, 'color': 4},
#      {'points': 10, 'color': 4},
#      {'points': 14, 'color': 4}],
#     'streak_sum': 34,
#     'value': 15798000,
#     'prev_value': 15758000,
#     'id_uc': 12250976,
#     'uc_name': 'J.e.acosta16',
#     'clause': 23697000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/464.png?version=20150723163906',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/222.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 21,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/21.png?version=20231018'}},
#    {'id': 7024,
#     'name': 'Fede Valverde',
#     'position': 3,
#     'id_team': 15,
#     'points': 72,
#     'avg': 8,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1498167188,
#     'streak': [{'points': 6, 'color': 3},
#      {'points': 5, 'color': 3},
#      {'points': 12, 'color': 4}],
#     'streak_sum': 23,
#     'value': 16513000,
#     'prev_value': 16494000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 24769500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/7024.png?version=20170622233308',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/15.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 17,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/17.png?version=20231018'}},
#    {'id': 53095,
#     'name': 'Bryan Zaragoza',
#     'position': 3,
#     'id_team': 10,
#     'points': 69,
#     'avg': 7.7,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1686899741,
#     'streak': [{'points': 9, 'color': 3},
#      {'points': 13, 'color': 4},
#      {'points': 18, 'color': 4}],
#     'streak_sum': 40,
#     'value': 10411000,
#     'prev_value': 10299000,
#     'id_uc': 12279221,
#     'uc_name': 'Alex',
#     'clause': 15616500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/53095.png?version=20230616091541',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/10.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 50,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/50.png?version=20231018'}},
#    {'id': 36371,
#     'name': 'Vedat Muriqi',
#     'position': 4,
#     'id_team': 408,
#     'points': 67,
#     'avg': 7.4,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1676921237,
#     'streak': [{'points': 14, 'color': 4},
#      {'points': 12, 'color': 4},
#      {'points': 8, 'color': 3}],
#     'streak_sum': 34,
#     'value': 15017000,
#     'prev_value': 14903000,
#     'id_uc': 12251120,
#     'uc_name': 'e 🏆🏆🏆🏆🏆🏆',
#     'clause': 22525500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 1,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/36371.png?version=20230220202717',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/408.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 16,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/16.png?version=20231018'}},
#    {'id': 343,
#     'name': 'Toni Kroos',
#     'position': 3,
#     'id_team': 15,
#     'points': 66,
#     'avg': 7.3,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1437662346,
#     'streak': [{'points': 3, 'color': 2},
#      {'points': 10, 'color': 4},
#      {'points': 4, 'color': 2}],
#     'streak_sum': 17,
#     'value': 13038000,
#     'prev_value': 13024000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 19557000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/343.png?version=20150723163906',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/15.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 17,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/17.png?version=20231018'}},
#    {'id': 3720,
#     'name': 'David López',
#     'position': 2,
#     'id_team': 222,
#     'points': 66,
#     'avg': 7.3,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1472222532,
#     'streak': [{'points': 6, 'color': 3},
#      {'points': 7, 'color': 3},
#      {'points': 7, 'color': 3}],
#     'streak_sum': 20,
#     'value': 12500000,
#     'prev_value': 12419000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 18750000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/3720.png?version=20160826164212',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/222.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 21,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/21.png?version=20231018'}},
#    {'id': 53099,
#     'name': 'Jonathan Viera',
#     'position': 3,
#     'id_team': 11,
#     'points': 64,
#     'avg': 7.1,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1686899907,
#     'streak': [{'points': 7, 'color': 3},
#      {'points': 13, 'color': 4},
#      {'points': 7, 'color': 3}],
#     'streak_sum': 27,
#     'value': 12332000,
#     'prev_value': 12277000,
#     'id_uc': 12285870,
#     'uc_name': 'Real Oviedo',
#     'clause': 18498000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/53099.png?version=20230616091827',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/11.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 14,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/14.png?version=20231018'}},
#    {'id': 48684,
#     'name': 'Robert Lewandowski',
#     'position': 4,
#     'id_team': 3,
#     'points': 62,
#     'avg': 7.8,
#     'status': 'injury',
#     'id_competition': 1,
#     'ts_pic': 1657987737,
#     'streak': [{'points': 4, 'color': 2},
#      {'points': 2, 'color': 2},
#      {'points': '-', 'color': 0}],
#     'streak_sum': 6,
#     'value': 21753000,
#     'prev_value': 21800000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 32629500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/48684.png?version=20220716180857',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 1,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018'}},
#    {'id': 3778,
#     'name': 'Joselu',
#     'position': 4,
#     'id_team': 15,
#     'points': 62,
#     'avg': 6.9,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1472726164,
#     'streak': [{'points': 9, 'color': 3},
#      {'points': 13, 'color': 4},
#      {'points': 7, 'color': 3}],
#     'streak_sum': 29,
#     'value': 15437000,
#     'prev_value': 15413000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 23155500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/3778.png?version=20160901123604',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/15.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 17,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/17.png?version=20231018'}},
#    {'id': 18186,
#     'name': 'Jules Koundé',
#     'position': 2,
#     'id_team': 3,
#     'points': 62,
#     'avg': 6.9,
#     'status': 'injury',
#     'id_competition': 1,
#     'ts_pic': 1676920796,
#     'streak': [{'points': 3, 'color': 2},
#      {'points': 6, 'color': 3},
#      {'points': 2, 'color': 2}],
#     'streak_sum': 11,
#     'value': 13846000,
#     'prev_value': 13998000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 20769000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/18186.png?version=20230220201956',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 1,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018'}},
#    {'id': 340,
#     'name': 'Isco',
#     'position': 3,
#     'id_team': 4,
#     'points': 62,
#     'avg': 6.9,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1690403641,
#     'streak': [{'points': 8, 'color': 3},
#      {'points': 10, 'color': 4},
#      {'points': 4, 'color': 2}],
#     'streak_sum': 22,
#     'value': 13180000,
#     'prev_value': 13076000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 19770000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/340.png?version=20230726223401',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/4.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 9,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/9.png?version=20231018'}},
#    {'id': 14791,
#     'name': 'Gorka Guruzeta',
#     'position': 4,
#     'id_team': 1,
#     'points': 62,
#     'avg': 6.9,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1534163285,
#     'streak': [{'points': 3, 'color': 2},
#      {'points': 3, 'color': 2},
#      {'points': 9, 'color': 3}],
#     'streak_sum': 15,
#     'value': 10677000,
#     'prev_value': 10670000,
#     'id_uc': 12260915,
#     'uc_name': 'Asier',
#     'clause': 16015500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/14791.png?version=20180813142805',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 3,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018'}},
#    {'id': 51,
#     'name': 'Antoine Griezmann',
#     'position': 4,
#     'id_team': 2,
#     'points': 60,
#     'avg': 7.5,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1437662345,
#     'streak': [{'points': 9, 'color': 3},
#      {'points': 6, 'color': 3},
#      {'points': 8, 'color': 3}],
#     'streak_sum': 23,
#     'value': 21652000,
#     'prev_value': 21647000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 32478000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/51.png?version=20150723163905',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/2.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 5,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/5.png?version=20231018'}},
#    {'id': 130,
#     'name': 'Iago Aspas',
#     'position': 4,
#     'id_team': 5,
#     'points': 60,
#     'avg': 6.7,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1437662345,
#     'streak': [{'points': 4, 'color': 2},
#      {'points': 4, 'color': 2},
#      {'points': 5, 'color': 3}],
#     'streak_sum': 13,
#     'value': 17756000,
#     'prev_value': 17826000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 26634000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/130.png?version=20150723163905',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/5.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 2,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/2.png?version=20231018'}},
#    {'id': 22930,
#     'name': 'Jeremías Ledesma',
#     'position': 1,
#     'id_team': 499,
#     'points': 60,
#     'avg': 6.7,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1686128757,
#     'streak': [{'points': 9, 'color': 3},
#      {'points': 6, 'color': 3},
#      {'points': 8, 'color': 3}],
#     'streak_sum': 23,
#     'value': 11298000,
#     'prev_value': 11249000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 16947000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/22930.png?version=20230607110557',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/499.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 19,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/19.png?version=20231018'}},
#    {'id': 14911,
#     'name': 'Álvaro García',
#     'position': 3,
#     'id_team': 14,
#     'points': 60,
#     'avg': 6.7,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1535113647,
#     'streak': [{'points': 4, 'color': 2},
#      {'points': 11, 'color': 4},
#      {'points': 9, 'color': 3}],
#     'streak_sum': 24,
#     'value': 10952000,
#     'prev_value': 10898000,
#     'id_uc': 12285870,
#     'uc_name': 'Real Oviedo',
#     'clause': 16428000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/14911.png?version=20180824142727',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/14.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 11,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/11.png?version=20231018'}},
#    {'id': 40166,
#     'name': 'Aurélien Tchouaméni',
#     'position': 3,
#     'id_team': 15,
#     'points': 59,
#     'avg': 6.6,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1654950452,
#     'streak': [{'points': 4, 'color': 2},
#      {'points': 14, 'color': 4},
#      {'points': 7, 'color': 3}],
#     'streak_sum': 25,
#     'value': 12641000,
#     'prev_value': 12604000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 18961500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/40166.png?version=20220611142732',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/15.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 17,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/17.png?version=20231018'}},
#    {'id': 607,
#     'name': 'Borja Mayoral',
#     'position': 4,
#     'id_team': 9,
#     'points': 59,
#     'avg': 6.6,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1456770949,
#     'streak': [{'points': 3, 'color': 2},
#      {'points': 4, 'color': 2},
#      {'points': 13, 'color': 4}],
#     'streak_sum': 20,
#     'value': 9656000,
#     'prev_value': 9519000,
#     'id_uc': 12256111,
#     'uc_name': 'G',
#     'clause': 14484000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/607.png?version=20160229193549',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/9.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 4,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/4.png?version=20231018'}},
#    {'id': 17459,
#     'name': 'Rodrygo',
#     'position': 4,
#     'id_team': 15,
#     'points': 58,
#     'avg': 6.4,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1558544639,
#     'streak': [{'points': 8, 'color': 3},
#      {'points': 4, 'color': 2},
#      {'points': 2, 'color': 2}],
#     'streak_sum': 14,
#     'value': 16398000,
#     'prev_value': 16458000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 24597000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/17459.png?version=20190522190359',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/15.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 17,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/17.png?version=20231018'}},
#    {'id': 11091,
#     'name': 'Brais Méndez',
#     'position': 3,
#     'id_team': 16,
#     'points': 58,
#     'avg': 6.4,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1506034328,
#     'streak': [{'points': 1, 'color': 2},
#      {'points': 5, 'color': 3},
#      {'points': 7, 'color': 3}],
#     'streak_sum': 13,
#     'value': 15173000,
#     'prev_value': 15178000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 22759500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/11091.png?version=20170922005208',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/16.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 408,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/408.png?version=20231018'}},
#    {'id': 52372,
#     'name': 'Javier Guerra',
#     'position': 3,
#     'id_team': 19,
#     'points': 58,
#     'avg': 6.4,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1691737146,
#     'streak': [{'points': 6, 'color': 3},
#      {'points': 0, 'color': 0},
#      {'points': 5, 'color': 3}],
#     'streak_sum': 11,
#     'value': 12609000,
#     'prev_value': 12559000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 18913500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/52372.png?version=20230811085906',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/19.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 499,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/499.png?version=20231018'}},
#    {'id': 54868,
#     'name': 'Sávio',
#     'position': 4,
#     'id_team': 222,
#     'points': 58,
#     'avg': 6.4,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1689341349,
#     'streak': [{'points': 8, 'color': 3},
#      {'points': 0, 'color': 0},
#      {'points': 5, 'color': 3}],
#     'streak_sum': 13,
#     'value': 11058000,
#     'prev_value': 10988000,
#     'id_uc': 12374305,
#     'uc_name': 'El Jeke👳\u200d♂️(The Best)😎',
#     'clause': 16587000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/54868.png?version=20230714152909',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/222.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 21,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/21.png?version=20231018'}},
#    {'id': 23173,
#     'name': 'Sergio Arribas',
#     'position': 3,
#     'id_team': 21,
#     'points': 58,
#     'avg': 6.4,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1691599263,
#     'streak': [{'points': 2, 'color': 2},
#      {'points': 5, 'color': 3},
#      {'points': 2, 'color': 2}],
#     'streak_sum': 9,
#     'value': 8771000,
#     'prev_value': 8695000,
#     'id_uc': 12253360,
#     'uc_name': 'Hhnegro Blanco',
#     'clause': 13156500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/23173.png?version=20230809184103',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/21.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 222,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/222.png?version=20231018'}},
#    {'id': 28794,
#     'name': 'Filip Jörgensen',
#     'position': 1,
#     'id_team': 20,
#     'points': 58,
#     'avg': 6.4,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1676921543,
#     'streak': [{'points': 4, 'color': 2},
#      {'points': 12, 'color': 4},
#      {'points': 5, 'color': 3}],
#     'streak_sum': 21,
#     'value': 7979000,
#     'prev_value': 7883000,
#     'id_uc': 12260539,
#     'uc_name': 'Victor',
#     'clause': 11968500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/28794.png?version=20230220203223',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/20.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 48,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/48.png?version=20231018'}},
#    {'id': 15566,
#     'name': 'Yangel Herrera',
#     'position': 3,
#     'id_team': 222,
#     'points': 57,
#     'avg': 6.3,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1547662316,
#     'streak': [{'points': 3, 'color': 2},
#      {'points': 4, 'color': 2},
#      {'points': 5, 'color': 3}],
#     'streak_sum': 12,
#     'value': 10141000,
#     'prev_value': 10127000,
#     'id_uc': 12251120,
#     'uc_name': 'e 🏆🏆🏆🏆🏆🏆',
#     'clause': 15211500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 1,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/15566.png?version=20190116191156',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/222.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 21,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/21.png?version=20231018'}},
#    {'id': 22601,
#     'name': 'Pepelu',
#     'position': 3,
#     'id_team': 19,
#     'points': 56,
#     'avg': 6.2,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1693595639,
#     'streak': [{'points': 7, 'color': 3},
#      {'points': 5, 'color': 3},
#      {'points': 9, 'color': 3}],
#     'streak_sum': 21,
#     'value': 11721000,
#     'prev_value': 11639000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 17581500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/22601.png?version=20230901211359',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/19.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 499,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/499.png?version=20231018'}},
#    {'id': 53111,
#     'name': 'Álvaro Valles',
#     'position': 1,
#     'id_team': 11,
#     'points': 56,
#     'avg': 6.2,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1686899802,
#     'streak': [{'points': 10, 'color': 4},
#      {'points': 6, 'color': 3},
#      {'points': 5, 'color': 3}],
#     'streak_sum': 21,
#     'value': 10835000,
#     'prev_value': 10799000,
#     'id_uc': 12271845,
#     'uc_name': 'Pocholo',
#     'clause': 16252500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/53111.png?version=20230616091642',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/11.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 14,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/14.png?version=20231018'}},
#    {'id': 6032,
#     'name': 'Alex Remiro',
#     'position': 1,
#     'id_team': 16,
#     'points': 56,
#     'avg': 6.2,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1496015732,
#     'streak': [{'points': 6, 'color': 3},
#      {'points': 8, 'color': 3},
#      {'points': 5, 'color': 3}],
#     'streak_sum': 19,
#     'value': 10764000,
#     'prev_value': 10761000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 16146000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/6032.png?version=20170529015532',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/16.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 408,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/408.png?version=20231018'}},
#    {'id': 49341,
#     'name': 'Jørgen Strand Larsen',
#     'position': 4,
#     'id_team': 5,
#     'points': 56,
#     'avg': 6.2,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1662029163,
#     'streak': [{'points': 3, 'color': 2},
#      {'points': 8, 'color': 3},
#      {'points': 13, 'color': 4}],
#     'streak_sum': 24,
#     'value': 8854000,
#     'prev_value': 8703000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 13281000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/49341.png?version=20220901124603',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/5.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 2,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/2.png?version=20231018'}},
#    {'id': 431,
#     'name': 'João Cancelo',
#     'position': 2,
#     'id_team': 3,
#     'points': 55,
#     'avg': 9.2,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1693602216,
#     'streak': [{'points': 4, 'color': 2},
#      {'points': 10, 'color': 4},
#      {'points': 7, 'color': 3}],
#     'streak_sum': 21,
#     'value': 14154000,
#     'prev_value': 14058000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 21231000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/431.png?version=20230901230336',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 1,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018'}},
#    {'id': 52375,
#     'name': 'Lamine Yamal',
#     'position': 4,
#     'id_team': 3,
#     'points': 55,
#     'avg': 6.1,
#     'status': 'doubt',
#     'id_competition': 1,
#     'ts_pic': 1695105022,
#     'streak': [{'points': 5, 'color': 3},
#      {'points': 7, 'color': 3},
#      {'points': 11, 'color': 4}],
#     'streak_sum': 23,
#     'value': 10899000,
#     'prev_value': 10835000,
#     'id_uc': 12251007,
#     'uc_name': 'Guillem',
#     'clause': 16348500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/52375.png?version=20230919083022',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 1,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018'}},
#    {'id': 14811,
#     'name': 'Unai Simón',
#     'position': 1,
#     'id_team': 1,
#     'points': 55,
#     'avg': 6.1,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1534442576,
#     'streak': [{'points': 3, 'color': 2},
#      {'points': 1, 'color': 2},
#      {'points': 5, 'color': 3}],
#     'streak_sum': 9,
#     'value': 9556000,
#     'prev_value': 9666000,
#     'id_uc': 12256756,
#     'uc_name': 'Luis Fernando Prisuelos Fernandez',
#     'clause': 14334000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/14811.png?version=20180816200256',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 3,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018'}},
#    {'id': 23327,
#     'name': 'Luis Suárez',
#     'position': 4,
#     'id_team': 21,
#     'points': 54,
#     'avg': 6.8,
#     'status': 'injury',
#     'id_competition': 1,
#     'ts_pic': 1676920677,
#     'streak': [{'points': 6, 'color': 3},
#      {'points': 21, 'color': 4},
#      {'points': '-', 'color': 0}],
#     'streak_sum': 27,
#     'value': 3888000,
#     'prev_value': 4066000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 5832000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/23327.png?version=20230220201757',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/21.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 222,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/222.png?version=20231018'}},
#    {'id': 29235,
#     'name': 'Gavi',
#     'position': 3,
#     'id_team': 3,
#     'points': 54,
#     'avg': 6,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1627108104,
#     'streak': [{'points': 8, 'color': 3},
#      {'points': 6, 'color': 3},
#      {'points': 6, 'color': 3}],
#     'streak_sum': 20,
#     'value': 15245000,
#     'prev_value': 15233000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 22867500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/29235.png?version=20210724082824',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 1,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018'}},
#    {'id': 18004,
#     'name': 'Ante Budimir',
#     'position': 4,
#     'id_team': 50,
#     'points': 54,
#     'avg': 6,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1561747679,
#     'streak': [{'points': 6, 'color': 3},
#      {'points': 12, 'color': 4},
#      {'points': 1, 'color': 2}],
#     'streak_sum': 19,
#     'value': 10057000,
#     'prev_value': 10052000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 15085500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/18004.png?version=20190628204759',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/50.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 10,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/10.png?version=20231018'}},
#    {'id': 18109,
#     'name': 'Luis Rioja',
#     'position': 3,
#     'id_team': 48,
#     'points': 53,
#     'avg': 5.9,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1561994202,
#     'streak': [{'points': 4, 'color': 2},
#      {'points': 4, 'color': 2},
#      {'points': 6, 'color': 3}],
#     'streak_sum': 14,
#     'value': 9576000,
#     'prev_value': 9506000,
#     'id_uc': 12255471,
#     'uc_name': 'Néstor',
#     'clause': 14364000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/18109.png?version=20190701171642',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/48.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 20,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/20.png?version=20231018'}},
#    {'id': 55058,
#     'name': 'Artem Dovbyk',
#     'position': 4,
#     'id_team': 222,
#     'points': 53,
#     'avg': 5.9,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1691336705,
#     'streak': [{'points': 10, 'color': 4},
#      {'points': 4, 'color': 2},
#      {'points': 4, 'color': 2}],
#     'streak_sum': 18,
#     'value': 7812000,
#     'prev_value': 7689000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 11718000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/55058.png?version=20230806174505',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/222.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 21,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/21.png?version=20231018'}},
#    {'id': 476,
#     'name': 'Gerard Moreno',
#     'position': 4,
#     'id_team': 20,
#     'points': 52,
#     'avg': 7.4,
#     'status': 'doubt',
#     'id_competition': 1,
#     'ts_pic': 1437662346,
#     'streak': [{'points': '-', 'color': 0},
#      {'points': '-', 'color': 0},
#      {'points': 9, 'color': 3}],
#     'streak_sum': 9,
#     'value': 14800000,
#     'prev_value': 14729000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 22200000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/476.png?version=20150723163906',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/20.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 48,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/48.png?version=20231018'}},
#    {'id': 53407,
#     'name': 'İlkay Gündoğan',
#     'position': 3,
#     'id_team': 3,
#     'points': 52,
#     'avg': 5.8,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1687781939,
#     'streak': [{'points': 2, 'color': 2},
#      {'points': 6, 'color': 3},
#      {'points': 8, 'color': 3}],
#     'streak_sum': 16,
#     'value': 14215000,
#     'prev_value': 14166000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 21322500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/53407.png?version=20230626141859',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 1,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018'}},
#    {'id': 24739,
#     'name': 'Óscar Mingueza',
#     'position': 2,
#     'id_team': 5,
#     'points': 52,
#     'avg': 5.8,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1606243103,
#     'streak': [{'points': 7, 'color': 3},
#      {'points': 2, 'color': 2},
#      {'points': 6, 'color': 3}],
#     'streak_sum': 15,
#     'value': 9754000,
#     'prev_value': 9651000,
#     'id_uc': 12253360,
#     'uc_name': 'Hhnegro Blanco',
#     'clause': 14631000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/24739.png?version=20201124193823',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/5.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 2,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/2.png?version=20231018'}},
#    {'id': 53107,
#     'name': 'Sergi Cardona',
#     'position': 2,
#     'id_team': 11,
#     'points': 52,
#     'avg': 5.8,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1686900553,
#     'streak': [{'points': 3, 'color': 2},
#      {'points': 10, 'color': 4},
#      {'points': 8, 'color': 3}],
#     'streak_sum': 21,
#     'value': 5677000,
#     'prev_value': 5573000,
#     'id_uc': 12253360,
#     'uc_name': 'Hhnegro Blanco',
#     'clause': 8515500,
#     'shield': 0,
#     'fav': 1,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/53107.png?version=20230616092913',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/11.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 14,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/14.png?version=20231018'}},
#    {'id': 1708,
#     'name': 'Álvaro Morata',
#     'position': 4,
#     'id_team': 2,
#     'points': 51,
#     'avg': 7.3,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1466591180,
#     'streak': [{'points': -1, 'color': 1},
#      {'points': '-', 'color': 0},
#      {'points': 7, 'color': 3}],
#     'streak_sum': 6,
#     'value': 12740000,
#     'prev_value': 12684000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 19110000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/1708.png?version=20160622122620',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/2.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 5,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/5.png?version=20231018'}},
#    {'id': 564,
#     'name': 'Mikel Oyarzabal',
#     'position': 4,
#     'id_team': 16,
#     'points': 51,
#     'avg': 5.7,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1448148031,
#     'streak': [{'points': 3, 'color': 2},
#      {'points': 11, 'color': 4},
#      {'points': 10, 'color': 4}],
#     'streak_sum': 24,
#     'value': 11735000,
#     'prev_value': 11638000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 17602500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/564.png?version=20151122002031',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/16.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 408,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/408.png?version=20231018'}},
#    {'id': 23369,
#     'name': 'Juan Foyth',
#     'position': 2,
#     'id_team': 20,
#     'points': 51,
#     'avg': 5.7,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1601803815,
#     'streak': [{'points': 1, 'color': 2},
#      {'points': 5, 'color': 3},
#      {'points': 3, 'color': 2}],
#     'streak_sum': 9,
#     'value': 10164000,
#     'prev_value': 10216000,
#     'id_uc': 12260915,
#     'uc_name': 'Asier',
#     'clause': 15703500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/23369.png?version=20201004113015',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/20.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 48,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/48.png?version=20231018'}},
#    {'id': 17453,
#     'name': 'Frenkie De Jong',
#     'position': 3,
#     'id_team': 3,
#     'points': 50,
#     'avg': 8.3,
#     'status': 'injury',
#     'id_competition': 1,
#     'ts_pic': 1558544639,
#     'streak': [{'points': '-', 'color': 0},
#      {'points': '-', 'color': 0},
#      {'points': '-', 'color': 0}],
#     'streak_sum': 0,
#     'value': 14963000,
#     'prev_value': 15027000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 22444500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/17453.png?version=20190522190359',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 1,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018'}},
#    {'id': 11700,
#     'name': 'Ferran Torres',
#     'position': 4,
#     'id_team': 3,
#     'points': 50,
#     'avg': 6.3,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1517484575,
#     'streak': [{'points': 4, 'color': 2},
#      {'points': 3, 'color': 2},
#      {'points': 3, 'color': 2}],
#     'streak_sum': 10,
#     'value': 10382000,
#     'prev_value': 10420000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 15573000,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/11700.png?version=20180201122935',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20231018',
#     'match_info': {'is_home': True,
#      'rival_team_id': 1,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20231018'}},
#    {'id': 27517,
#     'name': 'Isi Palazón',
#     'position': 3,
#     'id_team': 14,
#     'points': 50,
#     'avg': 5.6,
#     'status': None,
#     'id_competition': 1,
#     'ts_pic': 1624256439,
#     'streak': [{'points': 4, 'color': 2},
#      {'points': 6, 'color': 3},
#      {'points': 2, 'color': 2}],
#     'streak_sum': 12,
#     'value': 14219000,
#     'prev_value': 14303000,
#     'id_uc': None,
#     'uc_name': None,
#     'clause': 21328500,
#     'shield': 0,
#     'fav': 0,
#     'id_market': None,
#     'is_mine': 0,
#     'photoUrl': 'https://cdn.gomister.com/file/cdn-common/players/27517.png?version=20210621082039',
#     'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/14.png?version=20231018',
#     'match_info': {'is_home': False,
#      'rival_team_id': 11,
#      'teamLogoUrl': 'https://cdn.gomister.com/file/cdn-common/teams/11.png?version=20231018'}}],
#   'teams': [{'id': 48, 'name': 'Alavés'},
#    {'id': 21, 'name': 'Almería'},
#    {'id': 1, 'name': 'Athletic Club'},
#    {'id': 2, 'name': 'Atlético'},
#    {'id': 3, 'name': 'Barcelona'},
#    {'id': 4, 'name': 'Betis'},
#    {'id': 499, 'name': 'Cádiz'},
#    {'id': 5, 'name': 'Celta'},
#    {'id': 9, 'name': 'Getafe'},
#    {'id': 222, 'name': 'Girona'},
#    {'id': 10, 'name': 'Granada'},
#    {'id': 11, 'name': 'Las Palmas'},
#    {'id': 408, 'name': 'Mallorca'},
#    {'id': 50, 'name': 'Osasuna'},
#    {'id': 14, 'name': 'Rayo Vallecano'},
#    {'id': 15, 'name': 'Real Madrid'},
#    {'id': 16, 'name': 'Real Sociedad'},
#    {'id': 17, 'name': 'Sevilla'},
#    {'id': 19, 'name': 'Valencia'},
#    {'id': 20, 'name': 'Villarreal'}],
#   'owners': [{'id': 12279221, 'name': 'Alex'},
#    {'id': 12259573, 'name': 'Andreuet10'},
#    {'id': 12260915, 'name': 'Asier'},
#    {'id': 12251120, 'name': 'e 🏆🏆🏆🏆🏆🏆'},
#    {'id': 12374305, 'name': 'El Jeke👳\u200d♂️(The Best)😎'},
#    {'id': 12256111, 'name': 'G'},
#    {'id': 12251007, 'name': 'Guillem'},
#    {'id': 12253360, 'name': 'Hhnegro Blanco'},
#    {'id': 12250976, 'name': 'J.e.acosta16'},
#    {'id': 12261681, 'name': 'Jose Daniel'},
#    {'id': 12279196, 'name': 'Julia'},
#    {'id': 12256756, 'name': 'Luis Fernando Prisuelos Fernandez'},
#    {'id': 12255471, 'name': 'Néstor'},
#    {'id': 12285601, 'name': 'PinoPerez'},
#    {'id': 12271845, 'name': 'Pocholo'},
#    {'id': 12285870, 'name': 'Real Oviedo'},
#    {'id': 12255740, 'name': 'Robjdr'},
#    {'id': 12260539, 'name': 'Victor'},
#    {'id': 12268509, 'name': 'YONI'}]}}

# %% [markdown]
# offset marks the first element to be returned by the API
# An array of "player:id" can be created here and request in a loop the individual player api calls, scrap the data, and fill the initial dataset...
